# %% [markdown]
# <a href="https://colab.research.google.com/github/wesszabo/Analizis-2-informatikusoknak/blob/El%C5%91ad%C3%A1s/MultiVariable_continuity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >[Table of Contents](#scrollTo=laFoxSf1EXIo)
#
# >>[1 Folytonosság](#scrollTo=L7dwXCLCSWWC)
#
# >>>[1.1 Példa](#scrollTo=FNKobSb6vRcA)

# %% [markdown]
# **Modulok**

# %%
from sympy import *
ip = get_ipython()
ibe = ip.configurables[-1]
ibe.figure_formats = { 'pdf', 'png'}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from IPython.display import HTML,Latex, display
import requests
import numpy as np
import sympy as sym
from sympy.solvers.solveset import solveset_real
from scipy import optimize
from numpy import pi, sin, cos
import plotly.graph_objects as go
from chart_studio.plotly import plot, iplot

# %%
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'colab'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery']

# %% [markdown]
# **Beállítások**

# %%
# Sympy to print formula not TeX
from sympy import init_printing
def custom_latex_printer(exp,**options):
    from google.colab.output._publish import javascript
    url = "https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default"
    javascript(url=url)
    return sym.printing.latex(exp,**options)
init_printing(use_latex="mathjax",latex_printer=custom_latex_printer)

# %%
x, y, z, alpha, beta = symbols('x y z alpha beta', real = True)

# %%
a, m, r, theta = symbols('a m r theta', real = True) # parameters

# %% [markdown]
# # Table of Contents

# %% [markdown]
# ## 1 Folytonosság

# %% [markdown]
# ###  1.1 Példa

# %% [markdown]
# <div class="exercises">
# Legyen
# $$
# f(x,y) =
# \begin{cases}
# \dfrac{x^2y}{x^4+y^2},      & \text{if  } x^2+y^2\neq 0;\\
# 0,        & \text{if  } x^2+y^2=0.
# \end{cases}
# $$
# Ekkor $f$ folytonos az origóban minden az origón áthaladó egyenes mentén,
# de mint kétváltozós függvény nem folytonos az origóban.
# </div>

# %%
def f(x,y):
    return x**2*y/(x**4+y**2)

# %%
Eq(f(x, m*x), simplify(f(x, m*x)))
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default'></script>
#       3
#    m⋅x         m⋅x
# ────────── = ───────
#  2  2    4    2    2
# m ⋅x  + x    m  + x

# %%
cc = Limit('f(x,mx)', x, 0)
Eq(cc, Limit(f(x,m*x), x, 0).doit())
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default'></script>
#  lim f(x, mx) = 0
# x─→0⁺

# %%
print('f(x,x**2) =',f(x,x**2))
# Out:
# f(x,x**2) = 1/2

# %%
xx = np.linspace(-3,3,100)
yy = np.linspace(-3,3,100)
X, Y = np.meshgrid(xx,yy)
z = f(xx,xx**2)
Z = f(X, Y)
fig = go.Figure(data=[go.Scatter3d(
    x = xx, y = xx**2,
    z = z,
    name = r'$f(x,x^2)$',
    marker = dict(
        size = 0,
    ),
    line = dict(
        color = 'green',
        width = 1
    )
    ),
    go.Scatter3d(
        x = xx, y = xx**2, z = [0 for _ in range(len(xx))],
        name = r'$f(x,x^2)\, \textrm{vetülete } x,y \textrm{ síkon}$',
        marker = dict(size = 0),
        line = dict(
            color = 'gray',
            width = 1
        )
        ),
    go.Surface(
        x=xx, y=yy, z=Z,
        contours_z=dict(show=True, 
                        usecolormap=True,
                        highlightcolor="limegreen", 
                        project_z=True)
        )
    ])
fig.update_layout(title=dict(
                  text=r'$\displaystyle{f(x,y)=\frac{x^2y}{x^4+y^2}}$',
                  font=dict(size=20)),
                  scene_camera_eye=dict(x=1.87, y=0.88, z=0.64),
                  width=700, height=700, 
                  margin=dict(l=65, r=80, b=65, t=70),
                  legend=go.layout.Legend(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=16,
            color="black"
        ),
        bgcolor="LightSteelBlue",
        bordercolor="Black",
        borderwidth=2
    )
)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="b74407d1-2f24-48b0-966d-db4667994f7c" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b74407d1-2f24-48b0-966d-db4667994f7c")) {
#                     Plotly.newPlot(
# ...
